# %%
import pandas as pd

# %%
data = pd.read_csv("./movie_metadata.csv")

# %%
data.country
# Out:
# 0          USA
# 1          USA
# 2           UK
# 3          USA
# 4          NaN
#          ...
# 5038    Canada
# 5039       USA
# 5040       USA
# 5041       USA
# 5042       USA
# Name: country, Length: 5043, dtype: object

# %%
data['country'].fillna("") # fillna() 用XX来填充空值
# Out:
# 0          USA
# 1          USA
# 2           UK
# 3          USA
# 4
#          ...
# 5038    Canada
# 5039       USA
# 5040       USA
# 5041       USA
# 5042       USA
# Name: country, Length: 5043, dtype: object

# %%
# 使用均值来填充电影时长字段的空值
data.duration = data.duration.fillna(data.duration.mean())

# %%
data.duration
# Out:
# 0       178.000000
# 1       169.000000
# 2       148.000000
# 3       164.000000
# 4       107.201074
#            ...
# 5038     87.000000
# 5039     43.000000
# 5040     76.000000
# 5041    100.000000
# 5042     90.000000
# Name: duration, Length: 5043, dtype: float64

# %%
data['title_year'].isnull().value_counts()
# Out:
# False    4935
# True      108
# Name: title_year, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5043 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
data.movie_title
# Out:
# 0                                                 Avatar
# 1               Pirates of the Caribbean: At World's End
# 2                                                Spectre
# 3                                  The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens    ...
#                               ...
# 5038                             Signed Sealed Delivered
# 5039                           The Following
# 5040                                A Plague So Pleasant
# 5041                                    Shanghai Calling
# 5042                                   My Date with Drew
# Name: movie_title, Length: 5043, dtype: object

# %%
data
# Out:
#       color      director_name  num_critic_for_reviews    duration  \
# 0     Color      James Cameron                   723.0  178.000000
# 1     Color     Gore Verbinski                   302.0  169.000000
# 2     Color         Sam Mendes                   602.0  148.000000
# 3     Color  Christopher Nolan                   813.0  164.000000
# 4       NaN        Doug Walker                     NaN  107.201074
# ...     ...                ...                     ...         ...
# 5038  Color        Scott Smith                     1.0   87.000000
# 5039  Color                NaN                    43.0   43.000000
# 5040  Color   Benjamin Roberds                    13.0   76.000000
# 5041  Color        Daniel Hsia                    14.0  100.000000
# 5042  Color           Jon Gunn                    43.0   90.000000
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
s1 = data.movie_title.str.strip()

# %%
s1.str.upper()
# Out:
# 0                                           AVATAR
# 1         PIRATES OF THE CARIBBEAN: AT WORLD'S END
# 2                                          SPECTRE
# 3                            THE DARK KNIGHT RISES
# 4       STAR WARS: EPISODE VII - THE FORCE AWAKENS
#                            ...
# 5038                       SIGNED SEALED DELIVERED
# 5039                                 THE FOLLOWING
# 5040                          A PLAGUE SO PLEASANT
# 5041                              SHANGHAI CALLING
# 5042                             MY DATE WITH DREW
# Name: movie_title, Length: 5043, dtype: object

# %%
s3 = data.director_name.str.strip()

# %%
data[["first_name","last_name","col1","col2"]] = s3.str.split(" ",expand=True)

# %%
data
# Out:
#       color      director_name  num_critic_for_reviews    duration  \
# 0     Color      James Cameron                   723.0  178.000000
# 1     Color     Gore Verbinski                   302.0  169.000000
# 2     Color         Sam Mendes                   602.0  148.000000
# 3     Color  Christopher Nolan                   813.0  164.000000
# 4       NaN        Doug Walker                     NaN  107.201074
# ...     ...                ...                     ...         ...
# 5038  Color        Scott Smith                     1.0   87.000000
# 5039  Color                NaN                    43.0   43.000000
# 5040  Color   Benjamin Roberds                    13.0   76.000000
# 5041  Color        Daniel Hsia                    14.0  100.000000
# 5042  Color           Jon Gunn                    43.0   90.000000
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
data[data.col1.isnull()^ True]
# Out:
#       color          director_name  num_critic_for_reviews  duration  \
# 52    Color     Guillermo del Toro                   575.0     131.0
# 139   Color    Jennifer Yuh Nelson                   284.0      90.0
# 140   Color     M. Night Shyamalan                   280.0     103.0
# 168   Color             Jon M. Chu                   351.0     122.0
# 179   Color  Alejandro G. Iñárritu                   556.0     156.0
# ...     ...                    ...                     ...       ...
# 4997  Color     David Gordon Green                    75.0      90.0
# 5002  Color     Collin Joseph Neal                     7.0      75.0
# 5003  Color      Bradley Rust Gray                    61.0      79.0
# 5031  Color     Thomas L. Phillips                    13.0      82.0
# 5034  Color       Neill Dela Llana                    35.0      80.0
#
#       director_facebook_likes  actor_3_facebook_likes         actor_2_name  \
# ...
